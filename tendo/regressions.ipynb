# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import seaborn as sns

from ISLP.models import ModelSpec as MS
import statsmodels.api as sm

# %%
df = pd.read_csv('file_for_regressions.csv', delimiter=';')

y = ['absolute', 'relative', 'lactate_delta', 'av_pow_w_kg',
       'B1_max_velocity', 'B1_avg_velocity', 'B1_max_displacement',
       'B1_avg_displacement', 'B1_max_force', 'B1_avg_force', 'B1_max_power',
       'B1_avg_power']
x = ['bodyweight(kg)', 'weight(kg)', 'reps',
       'sets','total_displacement', 'time_under_tension']


sns.pairplot(df, hue='training', kind='scatter', x_vars=x, y_vars=y)
